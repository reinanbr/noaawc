# %%
from noawclg import load

# %%
prate = load(date="02/05/2026",keys=["prate"])

# %%
prate = prate['prate']

# %%
da = prate

# %%
print(da.attrs)  # procure 'units'
print(da.values.max())  # veja o valor máximo real
print(da.values.mean())
# Out:
# {'long_name': 'Precipitation rate', 'units': 'kg m**-2 s**-1', 'gfs_run': '20260502 00Z'}
# 0.025145599618554115
# 2.9217243152348115e-05
